# %%
import torch
import torch.nn as nn
from torch import optim
import torch.nn.functional as F
import matplotlib.pyplot as plt
import numpy as np
from os import system
from nltk.translate.bleu_score import SmoothingFunction, sentence_bleu

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
SOS_token = 0
EOS_token = 1
#----------Hyper Parameters----------#
input_size = 28   
hidden_size = 256 # or 512
latent_size = 32
conditional_size = 8
lr = 0.05
epochs = 500
kl_annealing_type='cycle'
time = 2
load = 0

# %%
import copy
from MyDataLoader import MyDataLoader
from torch.utils.data import DataLoader
from model import *
from utils import *
from train import *
if __name__=='__main__':
    
    #create dir
    if not os.path.exists("./results"):
        os.makedirs("./results")
        
    if not os.path.exists("./models"):
        os.makedirs("./models")
    
    #load data
    train_data = MyDataLoader(path='lab5_dataset/train.txt', train=True)
    train_data = DataLoader(train_data, batch_size =1, shuffle=True,num_workers=8)
    test_data  = MyDataLoader(path='lab5_dataset/test.txt', train=False)
    test_data = DataLoader(test_data, batch_size =1, shuffle=False,num_workers=8)
    tensor2string = MyDataLoader(path='lab5_dataset/test.txt', train=False).tensor2string
    MAX_LENGTH = 1000 # all words len < 1000
    CVAE=CVAE(input_size,hidden_size,latent_size,conditional_size,max_length=MAX_LENGTH).to(device)
    
    # load best model and evaluation bleu score & gaussian score  
    if(load==1):
        path = 'models/best_CVAE_32_ckpt'
        CVAE.load_state_dict(torch.load(path))
        
        conversion, BLEUscore = evaluate(CVAE, test_data, tensor2string)
        total_BLEUscore=0
        total_Gaussianscore=0
        test_time=5
        for i in range(test_time):
            conversion, BLEUscore = evaluate(CVAE, test_data, tensor2string)
            print('test.txt prediction:')
            for i in range(len(conversion)):
                print('input:',conversion[i][0])
                print('target:',conversion[i][1])
                print('prediction:',conversion[i][2])
                print()
            total_BLEUscore+=BLEUscore
        print(f'avg BLEUscore {total_BLEUscore/test_time:.2f}')
    
        for i in range(test_time):    
            # generate words
            generated_words=Gaussian_generate(CVAE,latent_size, tensor2string)
            Gaussianscore=Gaussian_score(generated_words)
            print('generate 100 words with 4 different tenses:')
            print(generated_words)
            total_Gaussianscore+=Gaussianscore
        print()
        print(f'avg Gaussianscore {total_Gaussianscore/test_time:.2f}')

        
    else:
        CEloss_list,KLloss_list,BLEUscore_list,teacher_forcing_ratio_list,kl_weight_list,Gaussianscore_list=[],[],[],[],[],[]
        optimizer = optim.SGD(CVAE.parameters(),lr=lr)
        best_BLEUscore=0    
        for epoch in range(1,epochs+1):
            # get teacher_forcing rator & kl weight
            teacher_forcing_ratio = get_teacher_forcing_ratio(epoch, epochs)
            kl_weight = get_kl_weight(epoch, epochs, kl_annealing_type, time)

            #train & compute loss
            CEloss, KLloss,_ = train(CVAE, train_data, optimizer, teacher_forcing_ratio, kl_weight, tensor2string)
            CEloss_list.append(CEloss)
            KLloss_list.append(KLloss)
            teacher_forcing_ratio_list.append(teacher_forcing_ratio)
            kl_weight_list.append(kl_weight)
            print(f'epoch{epoch:>2d}/{epochs}  tf_ratio:{teacher_forcing_ratio:.2f}  kl_weight:{kl_weight:.2f}')
            print(f'CE:{CEloss:.4f} + KL:{KLloss:.4f} = {CEloss+KLloss:.4f}')

            """
            evalutation with test_data
            """
            predict,BLEUscore=evaluate(CVAE,test_data,tensor2string)
            #G
            generated_words=Gaussian_generate(CVAE,latent_size,tensor2string)
            Gaussianscore=Gaussian_score(generated_words)
            BLEUscore_list.append(BLEUscore)
            Gaussianscore_list.append(Gaussianscore)
            print(predict)
            print(f'BLEU socre:{BLEUscore:.4f} Gaussian score:{Gaussianscore:.4f}\n')

            """
            update best model
            """
            if( BLEUscore>=0.7 )and (Gaussianscore >=0.3):
                # save model
                torch.save(CVAE.state_dict(),os.path.join('models',f'best_epoch_{epoch}_BLEUscore_{BLEUscore}_Gaussianscore_{Gaussianscore}.ckpt'))
          
            """
            store results
            """
            fig=plot(epoch,CEloss_list,KLloss_list,BLEUscore_list,teacher_forcing_ratio_list,kl_weight_list)
            fig.savefig(os.path.join('results',f'result.png'))
            fig_withG=plot(epoch,CEloss_list,KLloss_list,BLEUscore_list,teacher_forcing_ratio_list,kl_weight_list,Gaussianscore_list)
            fig_withG.savefig(os.path.join('results',f'fig_with_gaussian.png'))
# Out:
# epoch 1/500  tf_ratio:1.00  kl_weight:0.00
# CE:2.1838 + KL:0.1845 = 2.3683
# [['abandon', 'abandoned', 'deasted'], ['abet', 'abetting', 'disting'], ['begin', 'begins', 'steat'], ['expend', 'expends', 'deasted'], ['sent', 'sends', 'desters'], ['split', 'splitting', 'disting'], ['flared', 'flare', 'deast'], ['functioning', 'function', 'stered'], ['functioning', 'functioned', 'deasted'], ['healing', 'heals', 'deasted']]
# BLEU socre:0.1127 Gaussian score:0.0000
#
# epoch 2/500  tf_ratio:1.00  kl_weight:0.00
# CE:1.8358 + KL:0.2253 = 2.0611
# [['abandon', 'abandoned', 'scraped'], ['abet', 'abetting', 'scraped'], ['begin', 'begins', 'scraps'], ['expend', 'expends', 'scraps'], ['sent', 'sends', 'seets'], ['split', 'splitting', 'scraped'], ['flared', 'flare', 'snap'], ['functioning', 'function', 'seet'], ['functioning', 'functioned', 'scraped'], ['healing', 'heals', 'scraps']]
# BLEU socre:0.0520 Gaussian score:0.0000
#
# epoch 3/500  tf_ratio:1.00  kl_weight:0.00
# CE:1.6827 + KL:0.2662 = 1.9489
# [['abandon', 'abandoned', 'surreaved'], ['abet', 'abetting', 'surreaving'], ['begin', 'begins', 'declails'], ['expend', 'expends', 'conters'], ['sent', 'sends', 'surresters'], ['split', 'splitting', 'surreaving'], ['flared', 'flare', 'scook'], ['functioning', 'function', 'surreave'], ['functioning', 'functioned', 'surreaved'], ['healing', 'heals', 'surresters']]
# BLEU socre:0.0498 Gaussian score:0.0000
#
# epoch 4/500  tf_ratio:0.99  kl_weight:0.00
# CE:1.5873 + KL:0.4084 = 1.9957
# [['abandon', 'abandoned', 'confered'], ['abet', 'abetting', 'adjounting'], ['begin', 'begins', 'conserts'], ['expend', 'expends', 'adoutes'], ['sent', 'sends', 'adoutes'], ['split', 'splitting', 'confering'], ['flared', 'flare', 'conferce'], ['functioning', 'function', 'confere'], ['functioning', 'functioned', 'confered'], ['healing', 'heals', 'conserts']]
# BLEU socre:0.0835 Gaussian score:0.0000
#
# epoch 5/500  tf_ratio:0.99  kl_weight:0.00
# CE:1.4691 + KL:4.9706 = 6.4397
# [['abandon', 'abandoned', 'spend'], ['abet', 'abetting', 'chuckling'], ['begin', 'begins', 'spends'], ['expend', 'expends', 'depends'], ['sent', 'sends', 'depairs'], ['split', 'splitting', 'borring'], ['flared', 'flare', 'spen'], ['functioning', 'function', 'spen'], ['functioning', 'functioned', 'belized'], ['healing', 'heals', 'spends']]
# BLEU socre:0.1230 Gaussian score:0.0000
#
# epoch 6/500  tf_ratio:0.99  kl_weight:0.00
# CE:1.3256 + KL:11.4718 = 12.7974
# [['abandon', 'abandoned', 'convened'], ['abet', 'abetting', 'convening'], ['begin', 'begins', 'stalks'], ['expend', 'expends', 'disagres'], ['sent', 'sends', 'convenes'], ['split', 'splitting', 'spuring'], ['flared', 'flare', 'stare'], ['functioning', 'function', 'bore'], ['functioning', 'functioned', 'outrand'], ['healing', 'heals', 'stares']]
# BLEU socre:0.0958 Gaussian score:0.3600
#
# epoch 7/500  tf_ratio:0.99  kl_weight:0.00
# CE:1.1019 + KL:23.7017 = 24.8036
# [['abandon', 'abandoned', 'accused'], ['abet', 'abetting', 'thranking'], ['begin', 'begins', 'behaves'], ['expend', 'expends', 'expects'], ['sent', 'sends', 'persends'], ['split', 'splitting', 'spilling'], ['flared', 'flare', 'filch'], ['functioning', 'function', 'snatch'], ['functioning', 'functioned', 'scared'], ['healing', 'heals', 'implores']]
# BLEU socre:0.1588 Gaussian score:0.0700
#
# epoch 8/500  tf_ratio:0.99  kl_weight:0.00
# CE:0.8409 + KL:35.2288 = 36.0697
# [['abandon', 'abandoned', 'abduded'], ['abet', 'abetting', 'abding'], ['begin', 'begins', 'bet'], ['expend', 'expends', 'experiences'], ['sent', 'sends', 'sends'], ['split', 'splitting', 'slaming'], ['flared', 'flare', 'flatter'], ['functioning', 'function', 'scrawl'], ['functioning', 'functioned', 'survived'], ['healing', 'heals', 'hides']]
# BLEU socre:0.2108 Gaussian score:0.0600
#
# epoch 9/500  tf_ratio:0.98  kl_weight:0.00
# CE:0.6381 + KL:41.6535 = 42.2916
# [['abandon', 'abandoned', 'abduded'], ['abet', 'abetting', 'attacking'], ['begin', 'begins', 'betrains'], ['expend', 'expends', 'expers'], ['sent', 'sends', 'sees'], ['split', 'splitting', 'spilling'], ['flared', 'flare', 'flick'], ['functioning', 'function', 'shrutter'], ['functioning', 'functioned', 'prohaigned'], ['healing', 'heals', 'hides']]
# BLEU socre:0.1523 Gaussian score:0.0300
#
# epoch10/500  tf_ratio:0.98  kl_weight:0.00
# CE:0.4900 + KL:46.4402 = 46.9302
# [['abandon', 'abandoned', 'abased'], ['abet', 'abetting', 'abttacking'], ['begin', 'begins', 'begines'], ['expend', 'expends', 'experiences'], ['sent', 'sends', 'steems'], ['split', 'splitting', 'slicking'], ['flared', 'flare', 'falt'], ['functioning', 'function', 'fumble'], ['functioning', 'functioned', 'fumbled'], ['healing', 'heals', 'heals']]
# BLEU socre:0.2652 Gaussian score:0.0400
#
# epoch11/500  tf_ratio:0.98  kl_weight:0.00
# CE:0.3997 + KL:48.2664 = 48.6661
# [['abandon', 'abandoned', 'absorded'], ['abet', 'abetting', 'battering'], ['begin', 'begins', 'begins'], ['expend', 'expends', 'expends'], ['sent', 'sends', 'sends'], ['split', 'splitting', 'spliting'], ['flared', 'flare', 'flare'], ['functioning', 'function', 'shrut'], ['functioning', 'functioned', 'funted'], ['healing', 'heals', 'heals']]
# BLEU socre:0.6163 Gaussian score:0.0500
# /home/frank/Desktop/HW/DLP_HW5_3/utils.py:66: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   fig = plt.figure(figsize=(8, 6))
# epoch12/500  tf_ratio:0.98  kl_weight:0.00
# CE:0.3071 + KL:49.9106 = 50.2176
# [['abandon', 'abandoned', 'abducded'], ['abet', 'abetting', 'battering'], ['begin', 'begins', 'begins'], ['expend', 'expends', 'expends'], ['sent', 'sends', 'sees'], ['split', 'splitting', 'spilling'], ['flared', 'flare', 'flare'], ['functioning', 'function', 'shrute'], ['functioning', 'functioned', 'furnished'], ['healing', 'heals', 'heaves']]
# BLEU socre:0.3893 Gaussian score:0.0300
#
# epoch13/500  tf_ratio:0.98  kl_weight:0.00
# CE:0.2475 + KL:50.6431 = 50.8906
# [['abandon', 'abandoned', 'abducted'], ['abet', 'abetting', 'abdictating'], ['begin', 'begins', 'begins'], ['expend', 'expends', 'expends'], ['sent', 'sends', 'sents'], ['split', 'splitting', 'spliting'], ['flared', 'flare', 'flame'], ['functioning', 'function', 'furmint'], ['functioning', 'functioned', 'fumbined'], ['healing', 'heals', 'heals']]
# BLEU socre:0.4898 Gaussian score:0.0200
#
# epoch14/500  tf_ratio:0.97  kl_weight:0.00
# CE:0.1929 + KL:48.8415 = 49.0344
# [['abandon', 'abandoned', 'abandoned'], ['abet', 'abetting', 'abetting'], ['begin', 'begins', 'begins'], ['expend', 'expends', 'expends'], ['sent', 'sends', 'snetters'], ['split', 'splitting', 'splitting'], ['flared', 'flare', 'flare'], ['functioning', 'function', 'fumbint'], ['functioning', 'functioned', 'functioned'], ['healing', 'heals', 'heals']]
# BLEU socre:0.8115 Gaussian score:0.0300
#
# epoch15/500  tf_ratio:0.97  kl_weight:0.00
# CE:0.1658 + KL:47.9284 = 48.0942
# [['abandon', 'abandoned', 'aboranted'], ['abet', 'abetting', 'abetting'], ['begin', 'begins', 'begins'], ['expend', 'expends', 'expends'], ['sent', 'sends', 'steers'], ['split', 'splitting', 'splitting'], ['flared', 'flare', 'flare'], ['functioning', 'function', 'function'], ['functioning', 'functioned', 'functioned'], ['healing', 'heals', 'heals']]
# BLEU socre:0.8145 Gaussian score:0.0200
#
# epoch16/500  tf_ratio:0.97  kl_weight:0.00
# CE:0.1568 + KL:46.3776 = 46.5344
# [['abandon', 'abandoned', 'abandoned'], ['abet', 'abetting', 'pattening'], ['begin', 'begins', 'begs'], ['expend', 'expends', 'expends'], ['sent', 'sends', 'sents'], ['split', 'splitting', 'splitting'], ['flared', 'flare', 'flare'], ['functioning', 'function', 'function'], ['functioning', 'functioned', 'functioned'], ['healing', 'heals', 'heals']]
# BLEU socre:0.7707 Gaussian score:0.0300
#
# epoch17/500  tf_ratio:0.97  kl_weight:0.00
# CE:0.1447 + KL:44.8205 = 44.9653
# [['abandon', 'abandoned', 'abandoned'], ['abet', 'abetting', 'abeting'], ['begin', 'begins', 'begins'], ['expend', 'expends', 'expends'], ['sent', 'sends', 'sents'], ['split', 'splitting', 'splaming'], ['flared', 'flare', 'flare'], ['functioning', 'function', 'function'], ['functioning', 'functioned', 'functioned'], ['healing', 'heals', 'heals']]
# BLEU socre:0.8179 Gaussian score:0.0500
#
# epoch18/500  tf_ratio:0.97  kl_weight:0.00
# CE:0.1121 + KL:43.5833 = 43.6954
# [['abandon', 'abandoned', 'abandoned'], ['abet', 'abetting', 'abetting'], ['begin', 'begins', 'begins'], ['expend', 'expends', 'expends'], ['sent', 'sends', 'sents'], ['split', 'splitting', 'splitting'], ['flared', 'flare', 'flare'], ['functioning', 'function', 'function'], ['functioning', 'functioned', 'functioned'], ['healing', 'heals', 'heles']]
# BLEU socre:0.8421 Gaussian score:0.0600
#
# epoch19/500  tf_ratio:0.96  kl_weight:0.00
# CE:0.1273 + KL:42.1506 = 42.2779
# [['abandon', 'abandoned', 'abonded'], ['abet', 'abetting', 'abetting'], ['begin', 'begins', 'begins'], ['expend', 'expends', 'expends'], ['sent', 'sends', 'sents'], ['split', 'splitting', 'splitting'], ['flared', 'flare', 'flare'], ['functioning', 'function', 'function'], ['functioning', 'functioned', 'functioned'], ['healing', 'heals', 'hells']]
# BLEU socre:0.7548 Gaussian score:0.0300
#
# epoch20/500  tf_ratio:0.96  kl_weight:0.00
# CE:0.1128 + KL:41.5896 = 41.7024
# [['abandon', 'abandoned', 'abandoned'], ['abet', 'abetting', 'abetting'], ['begin', 'begins', 'begins'], ['expend', 'expends', 'explands'], ['sent', 'sends', 'seeks'], ['split', 'splitting', 'specking'], ['flared', 'flare', 'flare'], ['functioning', 'function', 'function'], ['functioning', 'functioned', 'functioned'], ['healing', 'heals', 'heals']]
# BLEU socre:0.7509 Gaussian score:0.0800
#
# epoch21/500  tf_ratio:0.96  kl_weight:0.00
# CE:0.0926 + KL:39.6509 = 39.7435
# [['abandon', 'abandoned', 'abandoned'], ['abet', 'abetting', 'abetting'], ['begin', 'begins', 'begins'], ['expend', 'expends', 'expends'], ['sent', 'sends', 'sents'], ['split', 'splitting', 'splitting'], ['flared', 'flare', 'flail'], ['functioning', 'function', 'function'], ['functioning', 'functioned', 'functioned'], ['healing', 'heals', 'heals']]
# BLEU socre:0.8552 Gaussian score:0.0500
#
# epoch22/500  tf_ratio:0.96  kl_weight:0.00
# CE:0.0897 + KL:38.4353 = 38.5250
# [['abandon', 'abandoned', 'abandoned'], ['abet', 'abetting', 'abetting'], ['begin', 'begins', 'begins'], ['expend', 'expends', 'expends'], ['sent', 'sends', 'sents'], ['split', 'splitting', 'splitting'], ['flared', 'flare', 'flare'], ['functioning', 'function', 'function'], ['functioning', 'functioned', 'functioned'], ['healing', 'heals', 'heals']]
# BLEU socre:0.9286 Gaussian score:0.0500
#
# epoch23/500  tf_ratio:0.96  kl_weight:0.00
# CE:0.0898 + KL:38.1095 = 38.1994
# [['abandon', 'abandoned', 'abandoned'], ['abet', 'abetting', 'abetting'], ['begin', 'begins', 'bewails'], ['expend', 'expends', 'expends'], ['sent', 'sends', 'sents'], ['split', 'splitting', 'splitting'], ['flared', 'flare', 'flare'], ['functioning', 'function', 'jurnish'], ['functioning', 'functioned', 'functioned'], ['healing', 'heals', 'heals']]
# BLEU socre:0.7406 Gaussian score:0.0500
#
# epoch24/500  tf_ratio:0.95  kl_weight:0.00
# CE:0.0860 + KL:37.1475 = 37.2335
# [['abandon', 'abandoned', 'abandoned'], ['abet', 'abetting', 'abetting'], ['begin', 'begins', 'begins'], ['expend', 'expends', 'expends'], ['sent', 'sends', 'sents'], ['split', 'splitting', 'split'], ['flared', 'flare', 'flare'], ['functioning', 'function', 'function'], ['functioning', 'functioned', 'functioned'], ['healing', 'heals', 'heals']]
# BLEU socre:0.8735 Gaussian score:0.0600
#
# epoch25/500  tf_ratio:0.95  kl_weight:0.00
# CE:0.0907 + KL:36.3381 = 36.4288
# [['abandon', 'abandoned', 'abandoned'], ['abet', 'abetting', 'abetting'], ['begin', 'begins', 'begins'], ['expend', 'expends', 'expends'], ['sent', 'sends', 'seeks'], ['split', 'splitting', 'spliting'], ['flared', 'flare', 'flare'], ['functioning', 'function', 'function'], ['functioning', 'functioned', 'functioned'], ['healing', 'heals', 'heals']]
# BLEU socre:0.8868 Gaussian score:0.0300
#
# epoch26/500  tf_ratio:0.95  kl_weight:0.00
# CE:0.1058 + KL:36.6175 = 36.7233
# [['abandon', 'abandoned', 'abandoned'], ['abet', 'abetting', 'abetting'], ['begin', 'begins', 'begins'], ['expend', 'expends', 'expends'], ['sent', 'sends', 'sents'], ['split', 'splitting', 'splitting'], ['flared', 'flare', 'flare'], ['functioning', 'function', 'function'], ['functioning', 'functioned', 'functioned'], ['healing', 'heals', 'heals']]
# BLEU socre:0.9286 Gaussian score:0.0300
#
# epoch27/500  tf_ratio:0.95  kl_weight:0.00
# CE:0.1146 + KL:36.5553 = 36.6699
# [['abandon', 'abandoned', 'abandoned'], ['abet', 'abetting', 'abetting'], ['begin', 'begins', 'begins'], ['expend', 'expends', 'expends'], ['sent', 'sends', 'sents'], ['split', 'splitting', 'spliting'], ['flared', 'flare', 'flare'], ['functioning', 'function', 'function'], ['functioning', 'functioned', 'functioned'], ['healing', 'heals', 'heals']]
# BLEU socre:0.9028 Gaussian score:0.0600
#
# epoch28/500  tf_ratio:0.95  kl_weight:0.00
# CE:0.1785 + KL:36.3859 = 36.5644
# [['abandon', 'abandoned', 'abducted'], ['abet', 'abetting', 'abetting'], ['begin', 'begins', 'begs'], ['expend', 'expends', 'expends'], ['sent', 'sends', 'see'], ['split', 'splitting', 'spilling'], ['flared', 'flare', 'flare'], ['functioning', 'function', 'functionalize'], ['functioning', 'functioned', 'functioned'], ['healing', 'heals', 'heals']]
# BLEU socre:0.6198 Gaussian score:0.0300
#
# epoch29/500  tf_ratio:0.94  kl_weight:0.00
# CE:0.1620 + KL:37.5310 = 37.6930
# [['abandon', 'abandoned', 'abandoned'], ['abet', 'abetting', 'abetting'], ['begin', 'begins', 'begins'], ['expend', 'expends', 'expends'], ['sent', 'sends', 'sents'], ['split', 'splitting', 'splitting'], ['flared', 'flare', 'flare'], ['functioning', 'function', 'function'], ['functioning', 'functioned', 'functioned'], ['healing', 'heals', 'heals']]
# BLEU socre:0.9286 Gaussian score:0.0400
#
# epoch30/500  tf_ratio:0.94  kl_weight:0.00
# CE:0.1107 + KL:34.2221 = 34.3328
# [['abandon', 'abandoned', 'abandoned'], ['abet', 'abetting', 'abetting'], ['begin', 'begins', 'begins'], ['expend', 'expends', 'expends'], ['sent', 'sends', 'senses'], ['split', 'splitting', 'splitting'], ['flared', 'flare', 'flare'], ['functioning', 'function', 'function'], ['functioning', 'functioned', 'functioned'], ['healing', 'heals', 'heals']]
# BLEU socre:0.9217 Gaussian score:0.0600
#
# epoch31/500  tf_ratio:0.94  kl_weight:0.00
# CE:0.0898 + KL:32.6739 = 32.7638
# [['abandon', 'abandoned', 'abandoned'], ['abet', 'abetting', 'abetting'], ['begin', 'begins', 'begins'], ['expend', 'expends', 'expends'], ['sent', 'sends', 'sents'], ['split', 'splitting', 'split'], ['flared', 'flare', 'flare'], ['functioning', 'function', 'feature'], ['functioning', 'functioned', 'functioned'], ['healing', 'heals', 'heals']]
# BLEU socre:0.7773 Gaussian score:0.0300
#
# epoch32/500  tf_ratio:0.94  kl_weight:0.00
# CE:0.0984 + KL:32.3129 = 32.4113
# [['abandon', 'abandoned', 'abandoned'], ['abet', 'abetting', 'abeting'], ['begin', 'begins', 'begins'], ['expend', 'expends', 'expends'], ['sent', 'sends', 'sents'], ['split', 'splitting', 'split'], ['flared', 'flare', 'flare'], ['functioning', 'function', 'function'], ['functioning', 'functioned', 'functioned'], ['healing', 'heals', 'heals']]
# BLEU socre:0.8424 Gaussian score:0.0300
#
# epoch33/500  tf_ratio:0.94  kl_weight:0.00
# CE:0.1125 + KL:31.5870 = 31.6995
# [['abandon', 'abandoned', 'abandoned'], ['abet', 'abetting', 'abetting'], ['begin', 'begins', 'begins'], ['expend', 'expends', 'expends'], ['sent', 'sends', 'sents'], ['split', 'splitting', 'split'], ['flared', 'flare', 'flare'], ['functioning', 'function', 'function'], ['functioning', 'functioned', 'functioned'], ['healing', 'heals', 'heals']]
# BLEU socre:0.8735 Gaussian score:0.0900
#
# epoch34/500  tf_ratio:0.93  kl_weight:0.00
# CE:0.0993 + KL:30.7765 = 30.8758
# [['abandon', 'abandoned', 'abnowded'], ['abet', 'abetting', 'abetting'], ['begin', 'begins', 'begins'], ['expend', 'expends', 'expends'], ['sent', 'sends', 'sends'], ['split', 'splitting', 'spliming'], ['flared', 'flare', 'flare'], ['functioning', 'function', 'finctuone'], ['functioning', 'functioned', 'functioned'], ['healing', 'heals', 'heals']]
# BLEU socre:0.7693 Gaussian score:0.0500
#
# epoch35/500  tf_ratio:0.93  kl_weight:0.00
# CE:0.1053 + KL:30.7694 = 30.8748
# [['abandon', 'abandoned', 'abandoned'], ['abet', 'abetting', 'abetting'], ['begin', 'begins', 'bewis'], ['expend', 'expends', 'expends'], ['sent', 'sends', 'sents'], ['split', 'splitting', 'split'], ['flared', 'flare', 'flare'], ['functioning', 'function', 'function'], ['functioning', 'functioned', 'functioned'], ['healing', 'heals', 'heals']]
# BLEU socre:0.7846 Gaussian score:0.0500
#
# epoch36/500  tf_ratio:0.93  kl_weight:0.00
# CE:0.0805 + KL:29.7364 = 29.8169
# [['abandon', 'abandoned', 'abandoned'], ['abet', 'abetting', 'abetting'], ['begin', 'begins', 'begins'], ['expend', 'expends', 'expends'], ['sent', 'sends', 'sents'], ['split', 'splitting', 'splitting'], ['flared', 'flare', 'flare'], ['functioning', 'function', 'function'], ['functioning', 'functioned', 'functioned'], ['healing', 'heals', 'heals']]
# BLEU socre:0.9286 Gaussian score:0.0700
#
# epoch37/500  tf_ratio:0.93  kl_weight:0.00
# CE:0.0998 + KL:28.7899 = 28.8897
# [['abandon', 'abandoned', 'abandoned'], ['abet', 'abetting', 'abetting'], ['begin', 'begins', 'begins'], ['expend', 'expends', 'expends'], ['sent', 'sends', 'sents'], ['split', 'splitting', 'splitting'], ['flared', 'flare', 'flare'], ['functioning', 'function', 'fountini'], ['functioning', 'functioned', 'functioned'], ['healing', 'heals', 'heals']]
# BLEU socre:0.8381 Gaussian score:0.0800
#
# epoch38/500  tf_ratio:0.93  kl_weight:0.00
# CE:0.0826 + KL:27.9558 = 28.0384
# [['abandon', 'abandoned', 'abandoned'], ['abet', 'abetting', 'abetting'], ['begin', 'begins', 'begins'], ['expend', 'expends', 'expends'], ['sent', 'sends', 'sents'], ['split', 'splitting', 'splitting'], ['flared', 'flare', 'flare'], ['functioning', 'function', 'function'], ['functioning', 'functioned', 'functioned'], ['healing', 'heals', 'heals']]
# BLEU socre:0.9286 Gaussian score:0.0600
#
# epoch39/500  tf_ratio:0.92  kl_weight:0.00
# CE:0.1166 + KL:28.6471 = 28.7638
# [['abandon', 'abandoned', 'abandoned'], ['abet', 'abetting', 'abetting'], ['begin', 'begins', 'begins'], ['expend', 'expends', 'expends'], ['sent', 'sends', 'sents'], ['split', 'splitting', 'spliting'], ['flared', 'flare', 'flare'], ['functioning', 'function', 'function'], ['functioning', 'functioned', 'functioned'], ['healing', 'heals', 'heals']]
# BLEU socre:0.9028 Gaussian score:0.0500
#
# epoch40/500  tf_ratio:0.92  kl_weight:0.00
# CE:0.1215 + KL:28.0528 = 28.1742
# [['abandon', 'abandoned', 'abandoned'], ['abet', 'abetting', 'abet'], ['begin', 'begins', 'begins'], ['expend', 'expends', 'expends'], ['sent', 'sends', 'sents'], ['split', 'splitting', 'sliming'], ['flared', 'flare', 'flare'], ['functioning', 'function', 'function'], ['functioning', 'functioned', 'functioned'], ['healing', 'heals', 'heals']]
# BLEU socre:0.7815 Gaussian score:0.1300
#
# epoch41/500  tf_ratio:0.92  kl_weight:0.00
# CE:0.1126 + KL:27.7535 = 27.8661
# [['abandon', 'abandoned', 'abandoned'], ['abet', 'abetting', 'abetting'], ['begin', 'begins', 'begins'], ['expend', 'expends', 'expends'], ['sent', 'sends', 'sends'], ['split', 'splitting', 'spilling'], ['flared', 'flare', 'flare'], ['functioning', 'function', 'function'], ['functioning', 'functioned', 'functioned'], ['healing', 'heals', 'heals']]
# BLEU socre:0.9178 Gaussian score:0.1100
#
# epoch42/500  tf_ratio:0.92  kl_weight:0.00
# CE:0.1089 + KL:26.8616 = 26.9705
# [['abandon', 'abandoned', 'abandoned'], ['abet', 'abetting', 'abetting'], ['begin', 'begins', 'beggins'], ['expend', 'expends', 'expresses'], ['sent', 'sends', 'seets'], ['split', 'splitting', 'slimbing'], ['flared', 'flare', 'fal'], ['functioning', 'function', 'function'], ['functioning', 'functioned', 'functioned'], ['healing', 'heals', 'heals']]
# BLEU socre:0.6069 Gaussian score:0.1000
#
# epoch43/500  tf_ratio:0.92  kl_weight:0.00
# CE:0.1227 + KL:26.2803 = 26.4030
# [['abandon', 'abandoned', 'abandoned'], ['abet', 'abetting', 'abetting'], ['begin', 'begins', 'begins'], ['expend', 'expends', 'expends'], ['sent', 'sends', 'seets'], ['split', 'splitting', 'splitting'], ['flared', 'flare', 'flare'], ['functioning', 'function', 'function'], ['functioning', 'functioned', 'functioned'], ['healing', 'heals', 'heals']]
# BLEU socre:0.9126 Gaussian score:0.0900
#
# epoch44/500  tf_ratio:0.91  kl_weight:0.00
# CE:0.1372 + KL:26.9035 = 27.0406
# [['abandon', 'abandoned', 'abandoned'], ['abet', 'abetting', 'abetting'], ['begin', 'begins', 'begins'], ['expend', 'expends', 'expends'], ['sent', 'sends', 'sents'], ['split', 'splitting', 'splitting'], ['flared', 'flare', 'flare'], ['functioning', 'function', 'funtion'], ['functioning', 'functioned', 'funtioned'], ['healing', 'heals', 'heals']]
# BLEU socre:0.8470 Gaussian score:0.1300
#
# epoch45/500  tf_ratio:0.91  kl_weight:0.00
# CE:0.1022 + KL:25.5577 = 25.6599
# [['abandon', 'abandoned', 'abandoned'], ['abet', 'abetting', 'abetting'], ['begin', 'begins', 'begins'], ['expend', 'expends', 'expends'], ['sent', 'sends', 'sents'], ['split', 'splitting', 'splitting'], ['flared', 'flare', 'flare'], ['functioning', 'function', 'struct'], ['functioning', 'functioned', 'studied'], ['healing', 'heals', 'heals']]
# BLEU socre:0.7411 Gaussian score:0.1300
#
# epoch46/500  tf_ratio:0.91  kl_weight:0.00
# CE:0.1237 + KL:25.8923 = 26.0160
# [['abandon', 'abandoned', 'bankrolled'], ['abet', 'abetting', 'abetting'], ['begin', 'begins', 'begins'], ['expend', 'expends', 'expends'], ['sent', 'sends', 'sents'], ['split', 'splitting', 'split'], ['flared', 'flare', 'flare'], ['functioning', 'function', 'function'], ['functioning', 'functioned', 'funticing'], ['healing', 'heals', 'heals']]
# BLEU socre:0.7018 Gaussian score:0.1300
#
# epoch47/500  tf_ratio:0.91  kl_weight:0.00
# CE:0.1428 + KL:25.3986 = 25.5414
# [['abandon', 'abandoned', 'abandoned'], ['abet', 'abetting', 'abetting'], ['begin', 'begins', 'begins'], ['expend', 'expends', 'expends'], ['sent', 'sends', 'sents'], ['split', 'splitting', 'splits'], ['flared', 'flare', 'flare'], ['functioning', 'function', 'function'], ['functioning', 'functioned', 'functioned'], ['healing', 'heals', 'heals']]
# BLEU socre:0.8747 Gaussian score:0.0900
#
# epoch48/500  tf_ratio:0.91  kl_weight:0.00
# CE:0.1305 + KL:25.1700 = 25.3005
# [['abandon', 'abandoned', 'abandoned'], ['abet', 'abetting', 'abetting'], ['begin', 'begins', 'begins'], ['expend', 'expends', 'expends'], ['sent', 'sends', 'sees'], ['split', 'splitting', 'split'], ['flared', 'flare', 'flare'], ['functioning', 'function', 'function'], ['functioning', 'functioned', 'functioned'], ['healing', 'heals', 'heals']]
# BLEU socre:0.8596 Gaussian score:0.1600
#
# epoch49/500  tf_ratio:0.90  kl_weight:0.00
# CE:0.1523 + KL:24.7412 = 24.8935
# [['abandon', 'abandoned', 'abounded'], ['abet', 'abetting', 'abetting'], ['begin', 'begins', 'begins'], ['expend', 'expends', 'expends'], ['sent', 'sends', 'sents'], ['split', 'splitting', 'splating'], ['flared', 'flare', 'falter'], ['functioning', 'function', 'function'], ['functioning', 'functioned', 'functioned'], ['healing', 'heals', 'jeals']]
# BLEU socre:0.6550 Gaussian score:0.0700
#
# epoch50/500  tf_ratio:0.90  kl_weight:0.00
# CE:0.1383 + KL:23.9197 = 24.0581
# [['abandon', 'abandoned', 'abandoned'], ['abet', 'abetting', 'abeting'], ['begin', 'begins', 'begins'], ['expend', 'expends', 'expends'], ['sent', 'sends', 'sents'], ['split', 'splitting', 'splitting'], ['flared', 'flare', 'flare'], ['functioning', 'function', 'function'], ['functioning', 'functioned', 'functioned'], ['healing', 'heals', 'heals']]
# BLEU socre:0.8975 Gaussian score:0.0900
#
# epoch51/500  tf_ratio:0.90  kl_weight:0.00
# CE:0.1271 + KL:23.1995 = 23.3266
# [['abandon', 'abandoned', 'abandoned'], ['abet', 'abetting', 'abetting'], ['begin', 'begins', 'begins'], ['expend', 'expends', 'expends'], ['sent', 'sends', 'sents'], ['split', 'splitting', 'splitting'], ['flared', 'flare', 'flare'], ['functioning', 'function', 'function'], ['functioning', 'functioned', 'fumbled'], ['healing', 'heals', 'heals']]
# BLEU socre:0.8350 Gaussian score:0.0800
#
# epoch52/500  tf_ratio:0.90  kl_weight:0.01
# CE:0.1418 + KL:23.3706 = 23.5124
# [['abandon', 'abandoned', 'abandoned'], ['abet', 'abetting', 'abeting'], ['begin', 'begins', 'begins'], ['expend', 'expends', 'expands'], ['sent', 'sends', 'sends'], ['split', 'splitting', 'slapping'], ['flared', 'flare', 'flare'], ['functioning', 'function', 'function'], ['functioning', 'functioned', 'functioned'], ['healing', 'heals', 'heals']]
# BLEU socre:0.8109 Gaussian score:0.0900
#
# epoch53/500  tf_ratio:0.90  kl_weight:0.01
# CE:0.1236 + KL:22.9135 = 23.0371
# [['abandon', 'abandoned', 'abandoned'], ['abet', 'abetting', 'abetting'], ['begin', 'begins', 'begins'], ['expend', 'expends', 'expends'], ['sent', 'sends', 'sents'], ['split', 'splitting', 'slimming'], ['flared', 'flare', 'flare'], ['functioning', 'function', 'function'], ['functioning', 'functioned', 'functioned'], ['healing', 'heals', 'heals']]
# BLEU socre:0.8445 Gaussian score:0.1300
#
# epoch54/500  tf_ratio:0.89  kl_weight:0.01
# CE:0.1407 + KL:22.6080 = 22.7487
# [['abandon', 'abandoned', 'abandoned'], ['abet', 'abetting', 'abetting'], ['begin', 'begins', 'begins'], ['expend', 'expends', 'expiates'], ['sent', 'sends', 'sents'], ['split', 'splitting', 'splitting'], ['flared', 'flare', 'flare'], ['functioning', 'function', 'swumm'], ['functioning', 'functioned', 'functioned'], ['healing', 'heals', 'heals']]
# BLEU socre:0.7471 Gaussian score:0.1300
#
# epoch55/500  tf_ratio:0.89  kl_weight:0.01
# CE:0.1525 + KL:23.0167 = 23.1692
# [['abandon', 'abandoned', 'abandoned'], ['abet', 'abetting', 'abetting'], ['begin', 'begins', 'begins'], ['expend', 'expends', 'explodes'], ['sent', 'sends', 'sensts'], ['split', 'splitting', 'spilling'], ['flared', 'flare', 'flare'], ['functioning', 'function', 'function'], ['functioning', 'functioned', 'functioned'], ['healing', 'heals', 'heals']]
# BLEU socre:0.7559 Gaussian score:0.1300
#
# epoch56/500  tf_ratio:0.89  kl_weight:0.01
# CE:0.1628 + KL:22.7788 = 22.9417
# [['abandon', 'abandoned', 'abandoned'], ['abet', 'abetting', 'abdicing'], ['begin', 'begins', 'begins'], ['expend', 'expends', 'expresses'], ['sent', 'sends', 'snetts'], ['split', 'splitting', 'splitting'], ['flared', 'flare', 'flare'], ['functioning', 'function', 'function'], ['functioning', 'functioned', 'functioned'], ['healing', 'heals', 'helps']]
# BLEU socre:0.6501 Gaussian score:0.0900
#
# epoch57/500  tf_ratio:0.89  kl_weight:0.01
# CE:0.1515 + KL:22.0695 = 22.2210
# [['abandon', 'abandoned', 'abandoned'], ['abet', 'abetting', 'abeting'], ['begin', 'begins', 'begins'], ['expend', 'expends', 'expends'], ['sent', 'sends', 'sents'], ['split', 'splitting', 'split'], ['flared', 'flare', 'flare'], ['functioning', 'function', 'function'], ['functioning', 'functioned', 'functioned'], ['healing', 'heals', 'heals']]
# BLEU socre:0.8424 Gaussian score:0.1200
#
# epoch58/500  tf_ratio:0.89  kl_weight:0.01
# CE:0.1641 + KL:21.5442 = 21.7084
# [['abandon', 'abandoned', 'abandoned'], ['abet', 'abetting', 'abetting'], ['begin', 'begins', 'begins'], ['expend', 'expends', 'expends'], ['sent', 'sends', 'steans'], ['split', 'splitting', 'splitting'], ['flared', 'flare', 'flare'], ['functioning', 'function', 'function'], ['functioning', 'functioned', 'functioned'], ['healing', 'heals', 'heals']]
# BLEU socre:0.9058 Gaussian score:0.1400
#
# epoch59/500  tf_ratio:0.88  kl_weight:0.01
# CE:0.1428 + KL:21.4973 = 21.6401
# [['abandon', 'abandoned', 'announced'], ['abet', 'abetting', 'abetting'], ['begin', 'begins', 'begins'], ['expend', 'expends', 'expends'], ['sent', 'sends', 'sents'], ['split', 'splitting', 'split'], ['flared', 'flare', 'flare'], ['functioning', 'function', 'gutter'], ['functioning', 'functioned', 'wobbined'], ['healing', 'heals', 'heals']]
# BLEU socre:0.5971 Gaussian score:0.1100
#
# epoch60/500  tf_ratio:0.88  kl_weight:0.01
# CE:0.3013 + KL:23.5458 = 23.8471
# [['abandon', 'abandoned', 'abandoned'], ['abet', 'abetting', 'abetting'], ['begin', 'begins', 'begs'], ['expend', 'expends', 'expends'], ['sent', 'sends', 'senses'], ['split', 'splitting', 'plisting'], ['flared', 'flare', 'flare'], ['functioning', 'function', 'jump'], ['functioning', 'functioned', 'jeatured'], ['healing', 'heals', 'heals']]
# BLEU socre:0.6016 Gaussian score:0.0600
#
# epoch61/500  tf_ratio:0.88  kl_weight:0.01
# CE:0.2932 + KL:23.6935 = 23.9867
# [['abandon', 'abandoned', 'abandoned'], ['abet', 'abetting', 'abetting'], ['begin', 'begins', 'begs'], ['expend', 'expends', 'expends'], ['sent', 'sends', 'sents'], ['split', 'splitting', 'splitting'], ['flared', 'flare', 'flare'], ['functioning', 'function', 'jincher'], ['functioning', 'functioned', 'featured'], ['healing', 'heals', 'heals']]
# BLEU socre:0.6669 Gaussian score:0.0800
#
# epoch62/500  tf_ratio:0.88  kl_weight:0.01
# CE:0.2049 + KL:21.8171 = 22.0220
# [['abandon', 'abandoned', 'bankrolled'], ['abet', 'abetting', 'abetting'], ['begin', 'begins', 'belies'], ['expend', 'expends', 'expends'], ['sent', 'sends', 'seets'], ['split', 'splitting', 'split'], ['flared', 'flare', 'flare'], ['functioning', 'function', 'function'], ['functioning', 'functioned', 'functioned'], ['healing', 'heals', 'heals']]
# BLEU socre:0.6815 Gaussian score:0.0800
#
# epoch63/500  tf_ratio:0.88  kl_weight:0.01
# CE:0.2046 + KL:20.8008 = 21.0054
# [['abandon', 'abandoned', 'abanded'], ['abet', 'abetting', 'abetting'], ['begin', 'begins', 'befins'], ['expend', 'expends', 'expands'], ['sent', 'sends', 'sends'], ['split', 'splitting', 'splatting'], ['flared', 'flare', 'flare'], ['functioning', 'function', 'function'], ['functioning', 'functioned', 'functioned'], ['healing', 'heals', 'heals']]
# BLEU socre:0.7657 Gaussian score:0.0700
#
# epoch64/500  tf_ratio:0.87  kl_weight:0.01
# CE:0.1978 + KL:20.8122 = 21.0100
# [['abandon', 'abandoned', 'abandoned'], ['abet', 'abetting', 'abetting'], ['begin', 'begins', 'gives'], ['expend', 'expends', 'expends'], ['sent', 'sends', 'senses'], ['split', 'splitting', 'splitting'], ['flared', 'flare', 'flare'], ['functioning', 'function', 'function'], ['functioning', 'functioned', 'functioned'], ['healing', 'heals', 'heals']]
# BLEU socre:0.8328 Gaussian score:0.0900
#
# epoch65/500  tf_ratio:0.87  kl_weight:0.01
# CE:0.1957 + KL:20.1535 = 20.3493
# [['abandon', 'abandoned', 'abandoned'], ['abet', 'abetting', 'abetting'], ['begin', 'begins', 'belies'], ['expend', 'expends', 'expends'], ['sent', 'sends', 'seeks'], ['split', 'splitting', 'splitting'], ['flared', 'flare', 'flare'], ['functioning', 'function', 'function'], ['functioning', 'functioned', 'functioned'], ['healing', 'heals', 'heals']]
# BLEU socre:0.8228 Gaussian score:0.1000
#
# epoch66/500  tf_ratio:0.87  kl_weight:0.01
# CE:0.1664 + KL:19.4452 = 19.6116
# [['abandon', 'abandoned', 'abandoned'], ['abet', 'abetting', 'abetting'], ['begin', 'begins', 'begins'], ['expend', 'expends', 'expends'], ['sent', 'sends', 'sends'], ['split', 'splitting', 'splitting'], ['flared', 'flare', 'flare'], ['functioning', 'function', 'function'], ['functioning', 'functioned', 'stimulated'], ['healing', 'heals', 'heals']]
# BLEU socre:0.9067 Gaussian score:0.0800
#
# epoch67/500  tf_ratio:0.87  kl_weight:0.01
# CE:0.1936 + KL:19.6306 = 19.8241
# [['abandon', 'abandoned', 'abandoned'], ['abet', 'abetting', 'batting'], ['begin', 'begins', 'begins'], ['expend', 'expends', 'expresses'], ['sent', 'sends', 'sents'], ['split', 'splitting', 'sleaming'], ['flared', 'flare', 'flare'], ['functioning', 'function', 'function'], ['functioning', 'functioned', 'functioned'], ['healing', 'heals', 'hears']]
# BLEU socre:0.6424 Gaussian score:0.0900
#
# epoch68/500  tf_ratio:0.87  kl_weight:0.01
# CE:0.1893 + KL:19.1023 = 19.2916
# [['abandon', 'abandoned', 'abandoned'], ['abet', 'abetting', 'abeting'], ['begin', 'begins', 'begins'], ['expend', 'expends', 'expends'], ['sent', 'sends', 'sents'], ['split', 'splitting', 'split'], ['flared', 'flare', 'flare'], ['functioning', 'function', 'function'], ['functioning', 'functioned', 'functioned'], ['healing', 'heals', 'heals']]
# BLEU socre:0.8424 Gaussian score:0.0700
#
# epoch69/500  tf_ratio:0.86  kl_weight:0.01
# CE:0.1828 + KL:18.7195 = 18.9023
# [['abandon', 'abandoned', 'abandoned'], ['abet', 'abetting', 'abetting'], ['begin', 'begins', 'besigns'], ['expend', 'expends', 'expends'], ['sent', 'sends', 'sents'], ['split', 'splitting', 'plucking'], ['flared', 'flare', 'flare'], ['functioning', 'function', 'hount'], ['functioning', 'functioned', 'functioned'], ['healing', 'heals', 'heals']]
# BLEU socre:0.6622 Gaussian score:0.1300
#
# epoch70/500  tf_ratio:0.86  kl_weight:0.01
# CE:0.2097 + KL:18.5601 = 18.7698
# [['abandon', 'abandoned', 'abandoned'], ['abet', 'abetting', 'abetting'], ['begin', 'begins', 'begins'], ['expend', 'expends', 'expends'], ['sent', 'sends', 'sents'], ['split', 'splitting', 'split'], ['flared', 'flare', 'flare'], ['functioning', 'function', 'funct'], ['functioning', 'functioned', 'functioned'], ['healing', 'heals', 'heals']]
# BLEU socre:0.8284 Gaussian score:0.1100
#
# epoch71/500  tf_ratio:0.86  kl_weight:0.01
# CE:0.1807 + KL:18.1151 = 18.2958
# [['abandon', 'abandoned', 'abandoned'], ['abet', 'abetting', 'abetting'], ['begin', 'begins', 'begins'], ['expend', 'expends', 'expends'], ['sent', 'sends', 'sents'], ['split', 'splitting', 'splitting'], ['flared', 'flare', 'flare'], ['functioning', 'function', 'funting'], ['functioning', 'functioned', 'functioned'], ['healing', 'heals', 'heals']]
# BLEU socre:0.8472 Gaussian score:0.1800
#
# epoch72/500  tf_ratio:0.86  kl_weight:0.01
# CE:0.3391 + KL:19.4418 = 19.7809
# [['abandon', 'abandoned', 'abandoned'], ['abet', 'abetting', 'abetting'], ['begin', 'begins', 'bewists'], ['expend', 'expends', 'expends'], ['sent', 'sends', 'sents'], ['split', 'splitting', 'spilling'], ['flared', 'flare', 'flare'], ['functioning', 'function', 'function'], ['functioning', 'functioned', 'functioned'], ['healing', 'heals', 'happens']]
# BLEU socre:0.6594 Gaussian score:0.0700
#
# epoch73/500  tf_ratio:0.86  kl_weight:0.01
# CE:0.2822 + KL:18.9165 = 19.1987
# [['abandon', 'abandoned', 'abandoned'], ['abet', 'abetting', 'abetting'], ['begin', 'begins', 'begins'], ['expend', 'expends', 'expends'], ['sent', 'sends', 'sends'], ['split', 'splitting', 'splits'], ['flared', 'flare', 'flare'], ['functioning', 'function', 'function'], ['functioning', 'functioned', 'fournished'], ['healing', 'heals', 'heals']]
# BLEU socre:0.8522 Gaussian score:0.1000
#
# epoch74/500  tf_ratio:0.85  kl_weight:0.01
# CE:0.2504 + KL:18.0734 = 18.3238
# [['abandon', 'abandoned', 'abandoned'], ['abet', 'abetting', 'abets'], ['begin', 'begins', 'begins'], ['expend', 'expends', 'exends'], ['sent', 'sends', 'sents'], ['split', 'splitting', 'splitting'], ['flared', 'flare', 'flare'], ['functioning', 'function', 'forsweat'], ['functioning', 'functioned', 'fountining'], ['healing', 'heals', 'heals']]
# BLEU socre:0.6273 Gaussian score:0.0900
#
# epoch75/500  tf_ratio:0.85  kl_weight:0.01
# CE:0.2321 + KL:17.7674 = 17.9995
# [['abandon', 'abandoned', 'abandoned'], ['abet', 'abetting', 'abetting'], ['begin', 'begins', 'begs'], ['expend', 'expends', 'expens'], ['sent', 'sends', 'senses'], ['split', 'splitting', 'splits'], ['flared', 'flare', 'flare'], ['functioning', 'function', 'forswort'], ['functioning', 'functioned', 'functioned'], ['healing', 'heals', 'leaves']]
# BLEU socre:0.5750 Gaussian score:0.0900
#
# epoch76/500  tf_ratio:0.85  kl_weight:0.01
# CE:0.2138 + KL:17.2493 = 17.4631
# [['abandon', 'abandoned', 'abandoned'], ['abet', 'abetting', 'abetting'], ['begin', 'begins', 'begins'], ['expend', 'expends', 'expens'], ['sent', 'sends', 'sents'], ['split', 'splitting', 'splits'], ['flared', 'flare', 'flare'], ['functioning', 'function', 'function'], ['functioning', 'functioned', 'huntioned'], ['healing', 'heals', 'heals']]
# BLEU socre:0.8011 Gaussian score:0.0900
#
# epoch77/500  tf_ratio:0.85  kl_weight:0.01
# CE:0.2448 + KL:17.2604 = 17.5052
# [['abandon', 'abandoned', 'announced'], ['abet', 'abetting', 'abetting'], ['begin', 'begins', 'begins'], ['expend', 'expends', 'expends'], ['sent', 'sends', 'sents'], ['split', 'splitting', 'splits'], ['flared', 'flare', 'flare'], ['functioning', 'function', 'function'], ['functioning', 'functioned', 'functioned'], ['healing', 'heals', 'heals']]
# BLEU socre:0.7826 Gaussian score:0.1500
#
# epoch78/500  tf_ratio:0.85  kl_weight:0.01
# CE:0.2492 + KL:16.7346 = 16.9838
# [['abandon', 'abandoned', 'abandoned'], ['abet', 'abetting', 'abetting'], ['begin', 'begins', 'begs'], ['expend', 'expends', 'expends'], ['sent', 'sends', 'snows'], ['split', 'splitting', 'split'], ['flared', 'flare', 'flare'], ['functioning', 'function', 'forswoan'], ['functioning', 'functioned', 'functioned'], ['healing', 'heals', 'heals']]
# BLEU socre:0.6816 Gaussian score:0.1500
#
# epoch79/500  tf_ratio:0.84  kl_weight:0.01
# CE:0.2327 + KL:16.6489 = 16.8816
# [['abandon', 'abandoned', 'absonded'], ['abet', 'abetting', 'abetting'], ['begin', 'begins', 'begs'], ['expend', 'expends', 'expends'], ['sent', 'sends', 'sketches'], ['split', 'splitting', 'splitting'], ['flared', 'flare', 'flare'], ['functioning', 'function', 'function'], ['functioning', 'functioned', 'forswoaned'], ['healing', 'heals', 'heals']]
# BLEU socre:0.6515 Gaussian score:0.1500
#
# epoch80/500  tf_ratio:0.84  kl_weight:0.01
# CE:0.2683 + KL:16.5909 = 16.8592
# [['abandon', 'abandoned', 'abandoned'], ['abet', 'abetting', 'abetting'], ['begin', 'begins', 'begins'], ['expend', 'expends', 'expends'], ['sent', 'sends', 'sents'], ['split', 'splitting', 'splits'], ['flared', 'flare', 'flare'], ['functioning', 'function', 'function'], ['functioning', 'functioned', 'functioned'], ['healing', 'heals', 'helps']]
# BLEU socre:0.7882 Gaussian score:0.1800
#
# epoch81/500  tf_ratio:0.84  kl_weight:0.01
# CE:0.2767 + KL:16.4220 = 16.6987
# [['abandon', 'abandoned', 'abandoned'], ['abet', 'abetting', 'abetting'], ['begin', 'begins', 'begaves'], ['expend', 'expends', 'explodes'], ['sent', 'sends', 'sents'], ['split', 'splitting', 'spliting'], ['flared', 'flare', 'flare'], ['functioning', 'function', 'function'], ['functioning', 'functioned', 'fnuttioned'], ['healing', 'heals', 'helps']]
# BLEU socre:0.6074 Gaussian score:0.1500
#
# epoch82/500  tf_ratio:0.84  kl_weight:0.02
# CE:0.2667 + KL:16.2288 = 16.4955
# [['abandon', 'abandoned', 'bankrolled'], ['abet', 'abetting', 'abetting'], ['begin', 'begins', 'begins'], ['expend', 'expends', 'expends'], ['sent', 'sends', 'senses'], ['split', 'splitting', 'ploting'], ['flared', 'flare', 'flare'], ['functioning', 'function', 'function'], ['functioning', 'functioned', 'guntioned'], ['healing', 'heals', 'heals']]
# BLEU socre:0.7313 Gaussian score:0.1200
#
# epoch83/500  tf_ratio:0.84  kl_weight:0.02
# CE:0.2613 + KL:16.0462 = 16.3075
# [['abandon', 'abandoned', 'abandoned'], ['abet', 'abetting', 'abetting'], ['begin', 'begins', 'begins'], ['expend', 'expends', 'engoes'], ['sent', 'sends', 'sents'], ['split', 'splitting', 'spilling'], ['flared', 'flare', 'flare'], ['functioning', 'function', 'functure'], ['functioning', 'functioned', 'functioned'], ['healing', 'heals', 'heals']]
# BLEU socre:0.7068 Gaussian score:0.1400
#
# epoch84/500  tf_ratio:0.83  kl_weight:0.02
# CE:0.2925 + KL:15.7105 = 16.0029
# [['abandon', 'abandoned', 'abandoned'], ['abet', 'abetting', 'abeting'], ['begin', 'begins', 'begs'], ['expend', 'expends', 'expends'], ['sent', 'sends', 'seeks'], ['split', 'splitting', 'splitting'], ['flared', 'flare', 'flare'], ['functioning', 'function', 'volunteer'], ['functioning', 'functioned', 'functioned'], ['healing', 'heals', 'heals']]
# BLEU socre:0.7135 Gaussian score:0.1700
#
# epoch85/500  tf_ratio:0.83  kl_weight:0.02
# CE:0.2901 + KL:15.7378 = 16.0280
# [['abandon', 'abandoned', 'abandoned'], ['abet', 'abetting', 'abetting'], ['begin', 'begins', 'begs'], ['expend', 'expends', 'eveals'], ['sent', 'sends', 'seeks'], ['split', 'splitting', 'split'], ['flared', 'flare', 'flare'], ['functioning', 'function', 'function'], ['functioning', 'functioned', 'functioned'], ['healing', 'heals', 'heals']]
# BLEU socre:0.6880 Gaussian score:0.1300
#
# epoch86/500  tf_ratio:0.83  kl_weight:0.02
# CE:0.2870 + KL:15.1315 = 15.4185
# [['abandon', 'abandoned', 'abandoned'], ['abet', 'abetting', 'abetting'], ['begin', 'begins', 'begins'], ['expend', 'expends', 'expends'], ['sent', 'sends', 'skets'], ['split', 'splitting', 'smiling'], ['flared', 'flare', 'flare'], ['functioning', 'function', 'function'], ['functioning', 'functioned', 'functioned'], ['healing', 'heals', 'hilles']]
# BLEU socre:0.7290 Gaussian score:0.1100
#
# epoch87/500  tf_ratio:0.83  kl_weight:0.02
# CE:0.2956 + KL:14.8767 = 15.1724
# [['abandon', 'abandoned', 'abased'], ['abet', 'abetting', 'abetting'], ['begin', 'begins', 'begins'], ['expend', 'expends', 'expends'], ['sent', 'sends', 'sents'], ['split', 'splitting', 'splitting'], ['flared', 'flare', 'flare'], ['functioning', 'function', 'succeed'], ['functioning', 'functioned', 'guunted'], ['healing', 'heals', 'exhales']]
# BLEU socre:0.5630 Gaussian score:0.1000
#
# epoch88/500  tf_ratio:0.83  kl_weight:0.02
# CE:0.3026 + KL:14.8058 = 15.1085
# [['abandon', 'abandoned', 'abandoned'], ['abet', 'abetting', 'averting'], ['begin', 'begins', 'beshing'], ['expend', 'expends', 'expends'], ['sent', 'sends', 'seeks'], ['split', 'splitting', 'splitting'], ['flared', 'flare', 'flare'], ['functioning', 'function', 'fascinate'], ['functioning', 'functioned', 'fascinated'], ['healing', 'heals', 'lispens']]
# BLEU socre:0.4758 Gaussian score:0.1500
#
# epoch89/500  tf_ratio:0.82  kl_weight:0.02
# CE:0.3064 + KL:14.5814 = 14.8878
# [['abandon', 'abandoned', 'panned'], ['abet', 'abetting', 'abetting'], ['begin', 'begins', 'begins'], ['expend', 'expends', 'expands'], ['sent', 'sends', 'sents'], ['split', 'splitting', 'splits'], ['flared', 'flare', 'flare'], ['functioning', 'function', 'funct'], ['functioning', 'functioned', 'foundied'], ['healing', 'heals', 'heals']]
# BLEU socre:0.5799 Gaussian score:0.1100
#
# epoch90/500  tf_ratio:0.82  kl_weight:0.02
# CE:0.3028 + KL:14.3989 = 14.7017
# [['abandon', 'abandoned', 'abandoned'], ['abet', 'abetting', 'abetting'], ['begin', 'begins', 'begins'], ['expend', 'expends', 'expends'], ['sent', 'sends', 'sents'], ['split', 'splitting', 'splits'], ['flared', 'flare', 'flare'], ['functioning', 'function', 'function'], ['functioning', 'functioned', 'functioned'], ['healing', 'heals', 'heals']]
# BLEU socre:0.8747 Gaussian score:0.1800
#
# epoch91/500  tf_ratio:0.82  kl_weight:0.02
# CE:0.3096 + KL:14.1326 = 14.4422
# [['abandon', 'abandoned', 'abandoned'], ['abet', 'abetting', 'abetting'], ['begin', 'begins', 'begins'], ['expend', 'expends', 'expends'], ['sent', 'sends', 'knews'], ['split', 'splitting', 'splitting'], ['flared', 'flare', 'flare'], ['functioning', 'function', 'outshine'], ['functioning', 'functioned', 'functioned'], ['healing', 'heals', 'heals']]
# BLEU socre:0.8112 Gaussian score:0.1200
#
# epoch92/500  tf_ratio:0.82  kl_weight:0.02
# CE:0.3195 + KL:13.9048 = 14.2243
# [['abandon', 'abandoned', 'advanced'], ['abet', 'abetting', 'abetting'], ['begin', 'begins', 'begets'], ['expend', 'expends', 'expends'], ['sent', 'sends', 'sents'], ['split', 'splitting', 'splitsing'], ['flared', 'flare', 'flare'], ['functioning', 'function', 'fortisk'], ['functioning', 'functioned', 'functioned'], ['healing', 'heals', 'heals']]
# BLEU socre:0.6253 Gaussian score:0.1000
#
# epoch93/500  tf_ratio:0.82  kl_weight:0.02
# CE:0.2926 + KL:13.7684 = 14.0610
# [['abandon', 'abandoned', 'abandoned'], ['abet', 'abetting', 'accesting'], ['begin', 'begins', 'begins'], ['expend', 'expends', 'envye'], ['sent', 'sends', 'sends'], ['split', 'splitting', 'splitting'], ['flared', 'flare', 'flare'], ['functioning', 'function', 'fascinate'], ['functioning', 'functioned', 'functioned'], ['healing', 'heals', 'hallenges']]
# BLEU socre:0.6514 Gaussian score:0.1400
#
# epoch94/500  tf_ratio:0.81  kl_weight:0.02
# CE:0.3078 + KL:13.6477 = 13.9555
# [['abandon', 'abandoned', 'abandoned'], ['abet', 'abetting', 'abetting'], ['begin', 'begins', 'begins'], ['expend', 'expends', 'expends'], ['sent', 'sends', 'sends'], ['split', 'splitting', 'splitting'], ['flared', 'flare', 'flare'], ['functioning', 'function', 'function'], ['functioning', 'functioned', 'functioned'], ['healing', 'heals', 'glares']]
# BLEU socre:0.9058 Gaussian score:0.2200
#
# epoch95/500  tf_ratio:0.81  kl_weight:0.02
# CE:0.3175 + KL:13.3851 = 13.7026
# [['abandon', 'abandoned', 'bankrolled'], ['abet', 'abetting', 'abetting'], ['begin', 'begins', 'begans'], ['expend', 'expends', 'expends'], ['sent', 'sends', 'sents'], ['split', 'splitting', 'splitting'], ['flared', 'flare', 'flare'], ['functioning', 'function', 'forewarn'], ['functioning', 'functioned', 'functioned'], ['healing', 'heals', 'heals']]
# BLEU socre:0.6714 Gaussian score:0.2000
#
# epoch96/500  tf_ratio:0.81  kl_weight:0.02
# CE:0.3418 + KL:13.3370 = 13.6788
# [['abandon', 'abandoned', 'abandoned'], ['abet', 'abetting', 'beating'], ['begin', 'begins', 'begets'], ['expend', 'expends', 'expends'], ['sent', 'sends', 'sents'], ['split', 'splitting', 'splitting'], ['flared', 'flare', 'flare'], ['functioning', 'function', 'fuather'], ['functioning', 'functioned', 'functioned'], ['healing', 'heals', 'helps']]
# BLEU socre:0.6145 Gaussian score:0.1900
#
# epoch97/500  tf_ratio:0.81  kl_weight:0.02
# CE:0.3338 + KL:13.2090 = 13.5427
# [['abandon', 'abandoned', 'abounded'], ['abet', 'abetting', 'abering'], ['begin', 'begins', 'begins'], ['expend', 'expends', 'expends'], ['sent', 'sends', 'skents'], ['split', 'splitting', 'splitting'], ['flared', 'flare', 'flare'], ['functioning', 'function', 'function'], ['functioning', 'functioned', 'foundered'], ['healing', 'heals', 'hears']]
# BLEU socre:0.5791 Gaussian score:0.2200
#
# epoch98/500  tf_ratio:0.81  kl_weight:0.03
# CE:0.3537 + KL:12.8992 = 13.2529
# [['abandon', 'abandoned', 'abandoned'], ['abet', 'abetting', 'abetting'], ['begin', 'begins', 'begins'], ['expend', 'expends', 'expends'], ['sent', 'sends', 'sents'], ['split', 'splitting', 'splitting'], ['flared', 'flare', 'flare'], ['functioning', 'function', 'fusction'], ['functioning', 'functioned', 'functioned'], ['healing', 'heals', 'learns']]
# BLEU socre:0.7983 Gaussian score:0.2100
#
# epoch99/500  tf_ratio:0.80  kl_weight:0.03
# CE:0.3656 + KL:12.8069 = 13.1725
# [['abandon', 'abandoned', 'abounded'], ['abet', 'abetting', 'abetting'], ['begin', 'begins', 'begins'], ['expend', 'expends', 'expands'], ['sent', 'sends', 'sents'], ['split', 'splitting', 'spilling'], ['flared', 'flare', 'flare'], ['functioning', 'function', 'function'], ['functioning', 'functioned', 'fubmitted'], ['healing', 'heals', 'heals']]
# BLEU socre:0.5903 Gaussian score:0.1400
#
# epoch100/500  tf_ratio:0.80  kl_weight:0.03
# CE:0.3533 + KL:12.7832 = 13.1365
# [['abandon', 'abandoned', 'adjudged'], ['abet', 'abetting', 'abetting'], ['begin', 'begins', 'begins'], ['expend', 'expends', 'expends'], ['sent', 'sends', 'sends'], ['split', 'splitting', 'split'], ['flared', 'flare', 'flare'], ['functioning', 'function', 'function'], ['functioning', 'functioned', 'functioned'], ['healing', 'heals', 'heals']]
# BLEU socre:0.8511 Gaussian score:0.2200
#
# epoch101/500  tf_ratio:0.80  kl_weight:0.03
# CE:0.3634 + KL:12.6029 = 12.9663
# [['abandon', 'abandoned', 'abandoned'], ['abet', 'abetting', 'beating'], ['begin', 'begins', 'begins'], ['expend', 'expends', 'expends'], ['sent', 'sends', 'sents'], ['split', 'splitting', 'splitting'], ['flared', 'flare', 'flare'], ['functioning', 'function', 'function'], ['functioning', 'functioned', 'functioned'], ['healing', 'heals', 'heals']]
# BLEU socre:0.8726 Gaussian score:0.2700
#
# epoch102/500  tf_ratio:0.80  kl_weight:0.03
# CE:0.3824 + KL:12.6091 = 12.9915
# [['abandon', 'abandoned', 'abandoned'], ['abet', 'abetting', 'abeing'], ['begin', 'begins', 'begins'], ['expend', 'expends', 'expends'], ['sent', 'sends', 'sents'], ['split', 'splitting', 'splitting'], ['flared', 'flare', 'flare'], ['functioning', 'function', 'chummle'], ['functioning', 'functioned', 'unfermed'], ['healing', 'heals', 'helds']]
# BLEU socre:0.5767 Gaussian score:0.1700
#
# epoch103/500  tf_ratio:0.80  kl_weight:0.03
# CE:0.3859 + KL:12.2993 = 12.6852
# ...
# BLEU socre:0.7521 Gaussian score:0.1100
#
# epoch334/500  tf_ratio:0.33  kl_weight:0.02
# CE:0.2580 + KL:14.9024 = 15.1604
# [['abandon', 'abandoned', 'abandoned'], ['abet', 'abetting', 'abetting'], ['begin', 'begins', 'begins'], ['expend', 'expends', 'expends'], ['sent', 'sends', 'sents'], ['split', 'splitting', 'skimming'], ['flared', 'flare', 'fear'], ['functioning', 'function', 'function'], ['functioning', 'functioned', 'functioned'], ['healing', 'heals', 'heals']]
# BLEU socre:0.7581 Gaussian score:0.1500
#
# epoch335/500  tf_ratio:0.33  kl_weight:0.02
# CE:0.3656 + KL:15.9317 = 16.2974
# [['abandon', 'abandoned', 'abandoned'], ['abet', 'abetting', 'abetting'], ['begin', 'begins', 'begins'], ['expend', 'expends', 'expends'], ['sent', 'sends', 'sents'], ['split', 'splitting', 'splitting'], ['flared', 'flare', 'flare'], ['functioning', 'function', 'function'], ['functioning', 'functioned', 'unscrewted'], ['healing', 'heals', 'helds']]
# BLEU socre:0.7491 Gaussian score:0.0300
#
# epoch336/500  tf_ratio:0.33  kl_weight:0.02
# CE:0.3143 + KL:15.3326 = 15.6469
# [['abandon', 'abandoned', 'abandoned'], ['abet', 'abetting', 'aching'], ['begin', 'begins', 'begins'], ['expend', 'expends', 'expends'], ['sent', 'sends', 'sent'], ['split', 'splitting', 'spliting'], ['flared', 'flare', 'flare'], ['functioning', 'function', 'function'], ['functioning', 'functioned', 'functioned'], ['healing', 'heals', 'heals']]
# BLEU socre:0.8207 Gaussian score:0.0500
#
# epoch337/500  tf_ratio:0.33  kl_weight:0.02
# CE:0.3155 + KL:14.8891 = 15.2045
# [['abandon', 'abandoned', 'abandoned'], ['abet', 'abetting', 'abetting'], ['begin', 'begins', 'begins'], ['expend', 'expends', 'expends'], ['sent', 'sends', 'sent'], ['split', 'splitting', 'splitting'], ['flared', 'flare', 'flare'], ['functioning', 'function', 'nuhbittte'], ['functioning', 'functioned', 'flourished'], ['healing', 'heals', 'halls']]
# BLEU socre:0.6563 Gaussian score:0.0800
#
# epoch338/500  tf_ratio:0.32  kl_weight:0.02
# CE:0.3148 + KL:14.7774 = 15.0923
# [['abandon', 'abandoned', 'abandoned'], ['abet', 'abetting', 'abetting'], ['begin', 'begins', 'begins'], ['expend', 'expends', 'expends'], ['sent', 'sends', 'sents'], ['split', 'splitting', 'splitting'], ['flared', 'flare', 'flare'], ['functioning', 'function', 'futtiin'], ['functioning', 'functioned', 'stumulated'], ['healing', 'heals', 'hears']]
# BLEU socre:0.6715 Gaussian score:0.1200
#
# epoch339/500  tf_ratio:0.32  kl_weight:0.02
# CE:0.3214 + KL:14.3281 = 14.6494
# [['abandon', 'abandoned', 'abandoned'], ['abet', 'abetting', 'abetting'], ['begin', 'begins', 'begins'], ['expend', 'expends', 'expends'], ['sent', 'sends', 'sent'], ['split', 'splitting', 'spliting'], ['flared', 'flare', 'flare'], ['functioning', 'function', 'function'], ['functioning', 'functioned', 'stimulated'], ['healing', 'heals', 'heals']]
# BLEU socre:0.8119 Gaussian score:0.1200
#
# epoch340/500  tf_ratio:0.32  kl_weight:0.02
# CE:0.3090 + KL:14.2402 = 14.5493
# [['abandon', 'abandoned', 'announed'], ['abet', 'abetting', 'abetting'], ['begin', 'begins', 'begins'], ['expend', 'expends', 'expends'], ['sent', 'sends', 'snnns'], ['split', 'splitting', 'splitting'], ['flared', 'flare', 'flare'], ['functioning', 'function', 'function'], ['functioning', 'functioned', 'functioned'], ['healing', 'heals', 'heals']]
# BLEU socre:0.8230 Gaussian score:0.0600
#
# epoch341/500  tf_ratio:0.32  kl_weight:0.02
# CE:0.3260 + KL:14.0921 = 14.4181
# [['abandon', 'abandoned', 'abandoned'], ['abet', 'abetting', 'abeting'], ['begin', 'begins', 'begins'], ['expend', 'expends', 'expends'], ['sent', 'sends', 'knews'], ['split', 'splitting', 'splitting'], ['flared', 'flare', 'flare'], ['functioning', 'function', 'outshine'], ['functioning', 'functioned', 'functioned'], ['healing', 'heals', 'heals']]
# BLEU socre:0.7802 Gaussian score:0.0500
#
# epoch342/500  tf_ratio:0.32  kl_weight:0.02
# CE:0.3323 + KL:14.2218 = 14.5541
# [['abandon', 'abandoned', 'abandoned'], ['abet', 'abetting', 'abeting'], ['begin', 'begins', 'begins'], ['expend', 'expends', 'expends'], ['sent', 'sends', 'sent'], ['split', 'splitting', 'splitting'], ['flared', 'flare', 'flare'], ['functioning', 'function', 'nuhblit'], ['functioning', 'functioned', 'functioned'], ['healing', 'heals', 'heals']]
# BLEU socre:0.8040 Gaussian score:0.1400
#
# epoch343/500  tf_ratio:0.31  kl_weight:0.02
# CE:0.3435 + KL:14.2193 = 14.5628
# [['abandon', 'abandoned', 'abandoned'], ['abet', 'abetting', 'abetting'], ['begin', 'begins', 'begins'], ['expend', 'expends', 'expends'], ['sent', 'sends', 'knews'], ['split', 'splitting', 'splitting'], ['flared', 'flare', 'flare'], ['functioning', 'function', 'function'], ['functioning', 'functioned', 'fictionalized'], ['healing', 'heals', 'heals']]
# BLEU socre:0.8415 Gaussian score:0.0600
#
# epoch344/500  tf_ratio:0.31  kl_weight:0.02
# CE:0.5864 + KL:15.4425 = 16.0290
# [['abandon', 'abandoned', 'abandoned'], ['abet', 'abetting', 'abetting'], ['begin', 'begins', 'begins'], ['expend', 'expends', 'expends'], ['sent', 'sends', 'sents'], ['split', 'splitting', 'spliting'], ['flared', 'flare', 'flare'], ['functioning', 'function', 'function'], ['functioning', 'functioned', 'functioned'], ['healing', 'heals', 'fedes']]
# BLEU socre:0.8092 Gaussian score:0.0200
#
# epoch345/500  tf_ratio:0.31  kl_weight:0.02
# CE:0.5560 + KL:14.9468 = 15.5028
# [['abandon', 'abandoned', 'abandoned'], ['abet', 'abetting', 'acheig'], ['begin', 'begins', 'begins'], ['expend', 'expends', 'expends'], ['sent', 'sends', 'sents'], ['split', 'splitting', 'splitting'], ['flared', 'flare', 'flare'], ['functioning', 'function', 'function'], ['functioning', 'functioned', 'functioned'], ['healing', 'heals', 'heals']]
# BLEU socre:0.8327 Gaussian score:0.0500
#
# epoch346/500  tf_ratio:0.31  kl_weight:0.02
# CE:0.4871 + KL:14.6876 = 15.1747
# [['abandon', 'abandoned', 'abandoned'], ['abet', 'abetting', 'abetting'], ['begin', 'begins', 'begins'], ['expend', 'expends', 'expends'], ['sent', 'sends', 'sents'], ['split', 'splitting', 'slipping'], ['flared', 'flare', 'flare'], ['functioning', 'function', 'function'], ['functioning', 'functioned', 'functioned'], ['healing', 'heals', 'befals']]
# BLEU socre:0.7669 Gaussian score:0.0100
#
# epoch347/500  tf_ratio:0.31  kl_weight:0.02
# CE:0.4707 + KL:14.5459 = 15.0167
# [['abandon', 'abandoned', 'abandoned'], ['abet', 'abetting', 'abeting'], ['begin', 'begins', 'geeiss'], ['expend', 'expends', 'expands'], ['sent', 'sends', 'sent'], ['split', 'splitting', 'slipsing'], ['flared', 'flare', 'flare'], ['functioning', 'function', 'understoo'], ['functioning', 'functioned', 'functioned'], ['healing', 'heals', 'heals']]
# BLEU socre:0.5558 Gaussian score:0.0200
#
# epoch348/500  tf_ratio:0.30  kl_weight:0.03
# CE:0.4306 + KL:13.8493 = 14.2798
# [['abandon', 'abandoned', 'absorbed'], ['abet', 'abetting', 'abeting'], ['begin', 'begins', 'begins'], ['expend', 'expends', 'expends'], ['sent', 'sends', 'sents'], ['split', 'splitting', 'spliting'], ['flared', 'flare', 'faar'], ['functioning', 'function', 'function'], ['functioning', 'functioned', 'futcinated'], ['healing', 'heals', 'hurls']]
# BLEU socre:0.5142 Gaussian score:0.0400
#
# epoch349/500  tf_ratio:0.30  kl_weight:0.03
# CE:0.4471 + KL:13.7557 = 14.2028
# [['abandon', 'abandoned', 'abandoned'], ['abet', 'abetting', 'abasing'], ['begin', 'begins', 'begins'], ['expend', 'expends', 'expands'], ['sent', 'sends', 'sents'], ['split', 'splitting', 'splitting'], ['flared', 'flare', 'faar'], ['functioning', 'function', 'function'], ['functioning', 'functioned', 'functioned'], ['healing', 'heals', 'heals']]
# BLEU socre:0.6885 Gaussian score:0.0500
#
# epoch350/500  tf_ratio:0.30  kl_weight:0.03
# CE:0.4317 + KL:13.5270 = 13.9586
# [['abandon', 'abandoned', 'abandoned'], ['abet', 'abetting', 'abasing'], ['begin', 'begins', 'begs'], ['expend', 'expends', 'expends'], ['sent', 'sends', 'sents'], ['split', 'splitting', 'spilting'], ['flared', 'flare', 'flare'], ['functioning', 'function', 'sugnhult'], ['functioning', 'functioned', 'functioned'], ['healing', 'heals', 'halls']]
# BLEU socre:0.5310 Gaussian score:0.0700
#
# epoch351/500  tf_ratio:0.30  kl_weight:0.03
# CE:0.4490 + KL:13.2285 = 13.6775
# [['abandon', 'abandoned', 'abandoned'], ['abet', 'abetting', 'abasting'], ['begin', 'begins', 'begins'], ['expend', 'expends', 'expines'], ['sent', 'sends', 'sents'], ['split', 'splitting', 'splitting'], ['flared', 'flare', 'flare'], ['functioning', 'function', 'function'], ['functioning', 'functioned', 'functioned'], ['healing', 'heals', 'hails']]
# BLEU socre:0.7026 Gaussian score:0.0700
#
# epoch352/500  tf_ratio:0.30  kl_weight:0.03
# CE:0.4469 + KL:13.6281 = 14.0750
# [['abandon', 'abandoned', 'abandoned'], ['abet', 'abetting', 'abetting'], ['begin', 'begins', 'begins'], ['expend', 'expends', 'expends'], ['sent', 'sends', 'sent'], ['split', 'splitting', 'splitting'], ['flared', 'flare', 'faare'], ['functioning', 'function', 'nutieont'], ['functioning', 'functioned', 'functioned'], ['healing', 'heals', 'heals']]
# BLEU socre:0.7687 Gaussian score:0.0700
#
# epoch353/500  tf_ratio:0.29  kl_weight:0.03
# CE:0.4516 + KL:13.0790 = 13.5305
# [['abandon', 'abandoned', 'scanned'], ['abet', 'abetting', 'abetting'], ['begin', 'begins', 'begins'], ['expend', 'expends', 'expends'], ['sent', 'sends', 'sent'], ['split', 'splitting', 'splitting'], ['flared', 'flare', 'flare'], ['functioning', 'function', 'function'], ['functioning', 'functioned', 'fiohiont'], ['healing', 'heals', 'heals']]
# BLEU socre:0.7586 Gaussian score:0.0900
#
# epoch354/500  tf_ratio:0.29  kl_weight:0.03
# CE:0.4624 + KL:12.7730 = 13.2354
# [['abandon', 'abandoned', 'abandoned'], ['abet', 'abetting', 'abeting'], ['begin', 'begins', 'begins'], ['expend', 'expends', 'expends'], ['sent', 'sends', 'sents'], ['split', 'splitting', 'splitting'], ['flared', 'flare', 'flare'], ['functioning', 'function', 'function'], ['functioning', 'functioned', 'fictionalized'], ['healing', 'heals', 'heals']]
# BLEU socre:0.8319 Gaussian score:0.0600
#
# epoch355/500  tf_ratio:0.29  kl_weight:0.03
# CE:0.4808 + KL:13.3324 = 13.8132
# [['abandon', 'abandoned', 'abandoned'], ['abet', 'abetting', 'abetting'], ['begin', 'begins', 'begins'], ['expend', 'expends', 'expends'], ['sent', 'sends', 'sents'], ['split', 'splitting', 'split'], ['flared', 'flare', 'flare'], ['functioning', 'function', 'function'], ['functioning', 'functioned', 'functioned'], ['healing', 'heals', 'heals']]
# BLEU socre:0.8735 Gaussian score:0.0900
#
# epoch356/500  tf_ratio:0.29  kl_weight:0.03
# CE:0.4905 + KL:13.0330 = 13.5235
# [['abandon', 'abandoned', 'abandoned'], ['abet', 'abetting', 'abetting'], ['begin', 'begins', 'begins'], ['expend', 'expends', 'expends'], ['sent', 'sends', 'sent'], ['split', 'splitting', 'spliting'], ['flared', 'flare', 'flare'], ['functioning', 'function', 'outshine'], ['functioning', 'functioned', 'nuttiiaued'], ['healing', 'heals', 'heals']]
# BLEU socre:0.7163 Gaussian score:0.1000
#
# epoch357/500  tf_ratio:0.29  kl_weight:0.03
# CE:0.5073 + KL:12.6428 = 13.1501
# [['abandon', 'abandoned', 'abandoned'], ['abet', 'abetting', 'abetting'], ['begin', 'begins', 'gegges'], ['expend', 'expends', 'expends'], ['sent', 'sends', 'sents'], ['split', 'splitting', 'splitting'], ['flared', 'flare', 'flare'], ['functioning', 'function', 'function'], ['functioning', 'functioned', 'flickered'], ['healing', 'heals', 'hails']]
# BLEU socre:0.6573 Gaussian score:0.0700
#
# epoch358/500  tf_ratio:0.28  kl_weight:0.03
# CE:0.5063 + KL:12.5795 = 13.0857
# [['abandon', 'abandoned', 'abandoned'], ['abet', 'abetting', 'abetting'], ['begin', 'begins', 'begins'], ['expend', 'expends', 'expends'], ['sent', 'sends', 'sents'], ['split', 'splitting', 'split'], ['flared', 'flare', 'flare'], ['functioning', 'function', 'authiont'], ['functioning', 'functioned', 'fncuulttteed'], ['healing', 'heals', 'heals']]
# BLEU socre:0.6950 Gaussian score:0.0900
#
# epoch359/500  tf_ratio:0.28  kl_weight:0.03
# CE:0.5102 + KL:12.4090 = 12.9192
# [['abandon', 'abandoned', 'abandoned'], ['abet', 'abetting', 'abetting'], ['begin', 'begins', 'begans'], ['expend', 'expends', 'eeeaps'], ['sent', 'sends', 'sonses'], ['split', 'splitting', 'splitting'], ['flared', 'flare', 'flare'], ['functioning', 'function', 'function'], ['functioning', 'functioned', 'authorized'], ['healing', 'heals', 'heals']]
# BLEU socre:0.6464 Gaussian score:0.0900
#
# epoch360/500  tf_ratio:0.28  kl_weight:0.04
# CE:0.5068 + KL:12.3465 = 12.8532
# [['abandon', 'abandoned', 'abandoned'], ['abet', 'abetting', 'abetting'], ['begin', 'begins', 'begs'], ['expend', 'expends', 'expends'], ['sent', 'sends', 'sents'], ['split', 'splitting', 'splitting'], ['flared', 'flare', 'flare'], ['functioning', 'function', 'furnish'], ['functioning', 'functioned', 'functioned'], ['healing', 'heals', 'heals']]
# BLEU socre:0.7617 Gaussian score:0.0400
#
# epoch361/500  tf_ratio:0.28  kl_weight:0.04
# CE:0.5160 + KL:12.2396 = 12.7556
# [['abandon', 'abandoned', 'abandoned'], ['abet', 'abetting', 'abetting'], ['begin', 'begins', 'gesses'], ['expend', 'expends', 'expends'], ['sent', 'sends', 'sent'], ['split', 'splitting', 'spiiting'], ['flared', 'flare', 'flare'], ['functioning', 'function', 'function'], ['functioning', 'functioned', 'nutieone'], ['healing', 'heals', 'heals']]
# BLEU socre:0.6909 Gaussian score:0.0300
#
# epoch362/500  tf_ratio:0.28  kl_weight:0.04
# CE:0.5272 + KL:12.1170 = 12.6442
# [['abandon', 'abandoned', 'abandoned'], ['abet', 'abetting', 'aettng'], ['begin', 'begins', 'leves'], ['expend', 'expends', 'eeples'], ['sent', 'sends', 'sents'], ['split', 'splitting', 'slicing'], ['flared', 'flare', 'fear'], ['functioning', 'function', 'fegchtte'], ['functioning', 'functioned', 'feitiated'], ['healing', 'heals', 'hells']]
# BLEU socre:0.2162 Gaussian score:0.0500
#
# epoch363/500  tf_ratio:0.27  kl_weight:0.04
# CE:0.5273 + KL:11.9641 = 12.4913
# [['abandon', 'abandoned', 'abandoned'], ['abet', 'abetting', 'abetting'], ['begin', 'begins', 'begins'], ['expend', 'expends', 'expares'], ['sent', 'sends', 'sends'], ['split', 'splitting', 'spliting'], ['flared', 'flare', 'flare'], ['functioning', 'function', 'function'], ['functioning', 'functioned', 'ferttlee'], ['healing', 'heals', 'hells']]
# BLEU socre:0.7117 Gaussian score:0.0300
#
# epoch364/500  tf_ratio:0.27  kl_weight:0.04
# CE:0.5217 + KL:11.9276 = 12.4492
# [['abandon', 'abandoned', 'abandoned'], ['abet', 'abetting', 'abeting'], ['begin', 'begins', 'begins'], ['expend', 'expends', 'expends'], ['sent', 'sends', 'sings'], ['split', 'splitting', 'splitting'], ['flared', 'flare', 'flare'], ['functioning', 'function', 'outshini'], ['functioning', 'functioned', 'functioned'], ['healing', 'heals', 'heals']]
# BLEU socre:0.7802 Gaussian score:0.0600
#
# epoch365/500  tf_ratio:0.27  kl_weight:0.04
# CE:0.5372 + KL:11.9470 = 12.4843
# [['abandon', 'abandoned', 'abandoned'], ['abet', 'abetting', 'abetting'], ['begin', 'begins', 'begets'], ['expend', 'expends', 'expects'], ['sent', 'sends', 'sents'], ['split', 'splitting', 'splitting'], ['flared', 'flare', 'flare'], ['functioning', 'function', 'muntionay'], ['functioning', 'functioned', 'functioned'], ['healing', 'heals', 'hells']]
# BLEU socre:0.6453 Gaussian score:0.0800
#
# epoch366/500  tf_ratio:0.27  kl_weight:0.04
# CE:0.5495 + KL:11.8140 = 12.3635
# [['abandon', 'abandoned', 'abandoned'], ['abet', 'abetting', 'attening'], ['begin', 'begins', 'chewing'], ['expend', 'expends', 'expends'], ['sent', 'sends', 'sents'], ['split', 'splitting', 'spilting'], ['flared', 'flare', 'flare'], ['functioning', 'function', 'function'], ['functioning', 'functioned', 'functioned'], ['healing', 'heals', 'heals']]
# BLEU socre:0.6947 Gaussian score:0.0800
#
# epoch367/500  tf_ratio:0.27  kl_weight:0.04
# CE:0.6082 + KL:11.7268 = 12.3350
# [['abandon', 'abandoned', 'abandoned'], ['abet', 'abetting', 'abusing'], ['begin', 'begins', 'begins'], ['expend', 'expends', 'expends'], ['sent', 'sends', 'sends'], ['split', 'splitting', 'splitting'], ['flared', 'flare', 'flare'], ['functioning', 'function', 'function'], ['functioning', 'functioned', 'functioned'], ['healing', 'heals', 'heals']]
# BLEU socre:0.9178 Gaussian score:0.1200
